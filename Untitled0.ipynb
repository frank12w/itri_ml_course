# %% [markdown]
# <a href="https://colab.research.google.com/github/frank12w/itri_ml_course/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import matplotlib.pyplot as plt 
print('hello, world')
# Out:
# hello, world

# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.linspace(0, 10, 21)
y = np.cos(x)
print(x)
plt.plot(x, y)
#plt.show() #兩張圖or一張圖
x = np.linspace(0, 10, 201)
y = np.sin(x)
plt.plot(x, y)
plt.show()
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10. ]
